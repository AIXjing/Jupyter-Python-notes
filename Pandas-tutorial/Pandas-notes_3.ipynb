# %% [markdown]
# # Reading/Writing Data to Different Sources
#
# Check up this [video](https://www.youtube.com/watch?v=N6hyN6BW6ao)
#
# The sytax basically the same:
#
# * read file: `pd.read_csv('file.csv')`, `pd.read_excel('file.xlsx')`, `pd.read_json('file.json')`
#
# * write file: `pd.to_csv('file.csv')`, `pd.to_excel('file.xlsx')`, `pd.to_json('file.json')`
#
#
# ## 1 csv file
#
# * read file: `pd.read_csv('path/file.csv')`
#
# * export to a csv file: `pd.to_csv('path/modified_file.csv')`
#
# * with a specific delimiter (e.g., tab): `pd.to_csv('path/modified_file.tsv', sep='\t')` the same for reading

# %%
import pandas as pd

#read csv file
df_2020=pd.read_csv('developer_survey_2020/survey_results_public.csv')

# %%
filt=(df_2020['Country'] == 'United States')
df_2020_US = df_2020.loc[filt]

df_2020_US.head()
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 4            5  I used to be a developer by profession, but no...      Yes
# 7            8                     I am a developer by profession      Yes
# 13          14                     I am a developer by profession      Yes
# 16          17                     I am a developer by profession      Yes
# 17          18                     I am a developer by profession      Yes
#
#      Age Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# 4   31.0         16      NaN        NaN            NaN  United States
# 7   36.0         12   Yearly   116000.0       116000.0  United States
# 13  27.0         13   Yearly    66000.0        66000.0  United States
# 16  25.0         14   Yearly    79000.0        79000.0  United States
# 17  32.0         12  Monthly   105000.0      1260000.0  United States
#
#             CurrencyDesc  ...                  SurveyEase  \
# 4                    NaN  ...                        Easy
# 7   United States dollar  ...                        Easy
# 13  United States dollar  ...  Neither easy nor difficult
# 16  United States dollar  ...                        Easy
# 17  United States dollar  ...  Neither easy nor difficult
#
#              SurveyLength Trans  \
# 4               Too short    No
# 7   Appropriate in length    No
# 13  Appropriate in length    No
# 16  Appropriate in length    No
# 17  Appropriate in length    No
#
#                                        UndergradMajor  \
# 4   Computer science, computer engineering, or sof...
# 7   Computer science, computer engineering, or sof...
# 13  Computer science, computer engineering, or sof...
# 16  Computer science, computer engineering, or sof...
# 17  Computer science, computer engineering, or sof...
#
#                  WebframeDesireNextYear  \
# 4                  Django;Ruby on Rails
# 7                Django;React.js;Vue.js
# 13                       Angular;Vue.js
# 16  ASP.NET Core;Gatsby;React.js;Vue.js
# 17                                  NaN
#
#                        WebframeWorkedWith  \
# 4                           Ruby on Rails
# 7                                   Flask
# 13                         Angular;Vue.js
# 16  ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 17                                    NaN
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 4   Just as welcome now as I felt last year         NaN        15            8
# 7   Just as welcome now as I felt last year        39.0        17           13
# 13  Just as welcome now as I felt last year        40.0         5            1
# 16  Just as welcome now as I felt last year        40.0         7            3
# 17  Just as welcome now as I felt last year        45.0        19           12
#
# [5 rows x 61 columns]

# %%
# write into a csv file

df_2020_US.to_csv('developer_survey_2020/US.csv')

# %%
# write it to a tsv file 

df_2020_US.to_csv('developer_survey_2020/US.tsv', sep='\t')

# %% [markdown]
# ## 2 xlsx file
#
# First, import library `pip install xlwt openpyxl xlrd`

# %%
# to write to excel file
df_2020_US.to_excel('developer_survey_2020/US.xlsx')

# %% [markdown]
# *Save to a specific sheet by adding a sheet arguement*

# %%
#read xlsx column
test_xlsx = pd.read_excel('developer_survey_2020/US.xlsx', index_col='Respondent')

# %%
test_xlsx
# Out:
#             Unnamed: 0                                         MainBranch  \
# Respondent
# 5                    4  I used to be a developer by profession, but no...
# 8                    7                     I am a developer by profession
# 14                  13                     I am a developer by profession
# 17                  16                     I am a developer by profession
# 18                  17                     I am a developer by profession
# ...                ...                                                ...
# 58498            64413                                                NaN
# 58896            64417                                                NaN
# 60931            64428                                                NaN
# 63077            64443                                                NaN
# 64858            64456                                                NaN
#
#            Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 5               Yes  31.0         16      NaN        NaN            NaN
# 8               Yes  36.0         12   Yearly   116000.0       116000.0
# 14              Yes  27.0         13   Yearly    66000.0        66000.0
# 17              Yes  25.0         14   Yearly    79000.0        79000.0
# 18              Yes  32.0         12  Monthly   105000.0      1260000.0
# ...             ...   ...        ...      ...        ...            ...
# 58498           Yes  32.0         23      NaN        NaN            NaN
# 58896           Yes  29.0         10      NaN        NaN            NaN
# 60931           Yes   NaN         17      NaN        NaN            NaN
# 63077           Yes   NaN         20      NaN        NaN            NaN
# 64858           Yes   NaN         16      NaN        NaN            NaN
#
#                   Country          CurrencyDesc  ...  \
# Respondent                                       ...
# 5           United States                   NaN  ...
# 8           United States  United States dollar  ...
# 14          United States  United States dollar  ...
# 17          United States  United States dollar  ...
# 18          United States  United States dollar  ...
# ...                   ...                   ...  ...
# 58498       United States                   NaN  ...
# 58896       United States                   NaN  ...
# 60931       United States                   NaN  ...
# 63077       United States                   NaN  ...
# 64858       United States                   NaN  ...
#
#                             SurveyEase           SurveyLength Trans  \
# Respondent
# 5                                 Easy              Too short    No
# 8                                 Easy  Appropriate in length    No
# 14          Neither easy nor difficult  Appropriate in length    No
# 17                                Easy  Appropriate in length    No
# 18          Neither easy nor difficult  Appropriate in length    No
# ...                                ...                    ...   ...
# 58498       Neither easy nor difficult  Appropriate in length    No
# 58896       Neither easy nor difficult  Appropriate in length    No
# 60931       Neither easy nor difficult               Too long    No
# 63077                              NaN                    NaN   NaN
# 64858                              NaN                    NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 5           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 14          Computer science, computer engineering, or sof...
# 17          Computer science, computer engineering, or sof...
# 18          Computer science, computer engineering, or sof...
# ...                                                       ...
# 58498                               Mathematics or statistics
# 58896       Computer science, computer engineering, or sof...
# 60931                           Web development or web design
# 63077       Computer science, computer engineering, or sof...
# 64858       Computer science, computer engineering, or sof...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 5                                        Django;Ruby on Rails
# 8                                      Django;React.js;Vue.js
# 14                                             Angular;Vue.js
# 17                        ASP.NET Core;Gatsby;React.js;Vue.js
# 18                                                        NaN
# ...                                                       ...
# 58498       ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React...
# 58896                                                     NaN
# 60931                                                     NaN
# 63077                                                     NaN
# 64858                                                     NaN
#
#                                            WebframeWorkedWith  \
# Respondent
# 5                                               Ruby on Rails
# 8                                                       Flask
# 14                                             Angular;Vue.js
# 17                      ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 18                                                        NaN
# ...                                                       ...
# 58498       ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React...
# 58896                                                     NaN
# 60931                                                  Drupal
# 63077                                                     NaN
# 64858                                                     NaN
#
#                                                 WelcomeChange WorkWeekHrs  \
# Respondent
# 5                     Just as welcome now as I felt last year         NaN
# 8                     Just as welcome now as I felt last year        39.0
# 14                    Just as welcome now as I felt last year        40.0
# 17                    Just as welcome now as I felt last year        40.0
# 18                    Just as welcome now as I felt last year        45.0
# ...                                                       ...         ...
# 58498                                                     NaN         NaN
# 58896                 Just as welcome now as I felt last year         NaN
# 60931       Not applicable - I did not use Stack Overflow ...         NaN
# 63077                                                     NaN         NaN
# 64858                                                     NaN         NaN
#
#            YearsCode      YearsCodePro
# Respondent
# 5                 15                 8
# 8                 17                13
# 14                 5                 1
# 17                 7                 3
# 18                19                12
# ...              ...               ...
# 58498              8  Less than 1 year
# 58896             29               NaN
# 60931              5               NaN
# 63077              4               NaN
# 64858             10  Less than 1 year
#
# [12469 rows x 61 columns]

# %% [markdown]
# # 3 Json

# %%
# Write data to json file

df_2020_US.to_json('developer_survey_2020/US.json', orient='records', lines=True)
# by adding arguement to make the data more list-like

# %%
# read a json file

test_json=pd.read_json('developer_survey_2020/US.json')

# %%
test_json.head(5)
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 4            5  I used to be a developer by profession, but no...      Yes
# 7            8                     I am a developer by profession      Yes
# 13          14                     I am a developer by profession      Yes
# 16          17                     I am a developer by profession      Yes
# 17          18                     I am a developer by profession      Yes
#
#      Age Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# 4   31.0         16     None        NaN            NaN  United States
# 7   36.0         12   Yearly   116000.0       116000.0  United States
# 13  27.0         13   Yearly    66000.0        66000.0  United States
# 16  25.0         14   Yearly    79000.0        79000.0  United States
# 17  32.0         12  Monthly   105000.0      1260000.0  United States
#
#             CurrencyDesc  ...                  SurveyEase  \
# 4                   None  ...                        Easy
# 7   United States dollar  ...                        Easy
# 13  United States dollar  ...  Neither easy nor difficult
# 16  United States dollar  ...                        Easy
# 17  United States dollar  ...  Neither easy nor difficult
#
#              SurveyLength Trans  \
# 4               Too short    No
# 7   Appropriate in length    No
# 13  Appropriate in length    No
# 16  Appropriate in length    No
# 17  Appropriate in length    No
#
#                                        UndergradMajor  \
# 4   Computer science, computer engineering, or sof...
# 7   Computer science, computer engineering, or sof...
# 13  Computer science, computer engineering, or sof...
# 16  Computer science, computer engineering, or sof...
# 17  Computer science, computer engineering, or sof...
#
#                  WebframeDesireNextYear  \
# 4                  Django;Ruby on Rails
# 7                Django;React.js;Vue.js
# 13                       Angular;Vue.js
# 16  ASP.NET Core;Gatsby;React.js;Vue.js
# 17                                 None
#
#                        WebframeWorkedWith  \
# 4                           Ruby on Rails
# 7                                   Flask
# 13                         Angular;Vue.js
# 16  ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 17                                   None
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 4   Just as welcome now as I felt last year         NaN        15            8
# 7   Just as welcome now as I felt last year        39.0        17           13
# 13  Just as welcome now as I felt last year        40.0         5            1
# 16  Just as welcome now as I felt last year        40.0         7            3
# 17  Just as welcome now as I felt last year        45.0        19           12
#
# [5 rows x 61 columns]

# %% [markdown]
# # 4 SQL
#
# ## 4.1 Create a connection with a database
#
# install a module to connect the database: `pip install SQLAlchemy`
#
# `psycopg2-binary` package propably is also needed.

# %%
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# **Hiding Passwords and Secret Keys in environmental viariables**
#
# Video [link](https://www.youtube.com/watch?v=5iWhQWVXosU)

# %%
#engine=create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')
engine=create_engine('sqlite:////Users/jingai/workspace/Jupyter-Python-notes/Pandas-tutorial/sample.db', echo=False)

# %% [markdown]
# ## 4.2 Write df to sql

# %%
df_2020_US.to_sql('developer_survey_2020/sample_table', engine, if_exists='replace')

# %% [markdown]
# ## 4.3 Write df to sql

# %%
df_sql=pd.read_sql('developer_survey_2020/sample_table', engine, index_col='Respondent')

# %%
df_sql.head()
# Out:
#             index                                         MainBranch Hobbyist  \
# Respondent
# 5               4  I used to be a developer by profession, but no...      Yes
# 8               7                     I am a developer by profession      Yes
# 14             13                     I am a developer by profession      Yes
# 17             16                     I am a developer by profession      Yes
# 18             17                     I am a developer by profession      Yes
#
#              Age Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# 5           31.0         16     None        NaN            NaN  United States
# 8           36.0         12   Yearly   116000.0       116000.0  United States
# 14          27.0         13   Yearly    66000.0        66000.0  United States
# 17          25.0         14   Yearly    79000.0        79000.0  United States
# 18          32.0         12  Monthly   105000.0      1260000.0  United States
#
#                     CurrencyDesc  ...                  SurveyEase  \
# Respondent                        ...
# 5                           None  ...                        Easy
# 8           United States dollar  ...                        Easy
# 14          United States dollar  ...  Neither easy nor difficult
# 17          United States dollar  ...                        Easy
# 18          United States dollar  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 5                       Too short    No
# 8           Appropriate in length    No
# 14          Appropriate in length    No
# 17          Appropriate in length    No
# 18          Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 5           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 14          Computer science, computer engineering, or sof...
# 17          Computer science, computer engineering, or sof...
# 18          Computer science, computer engineering, or sof...
#
#                          WebframeDesireNextYear  \
# Respondent
# 5                          Django;Ruby on Rails
# 8                        Django;React.js;Vue.js
# 14                               Angular;Vue.js
# 17          ASP.NET Core;Gatsby;React.js;Vue.js
# 18                                         None
#
#                                WebframeWorkedWith  \
# Respondent
# 5                                   Ruby on Rails
# 8                                           Flask
# 14                                 Angular;Vue.js
# 17          ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 18                                           None
#
#                                       WelcomeChange WorkWeekHrs YearsCode  \
# Respondent
# 5           Just as welcome now as I felt last year         NaN        15
# 8           Just as welcome now as I felt last year        39.0        17
# 14          Just as welcome now as I felt last year        40.0         5
# 17          Just as welcome now as I felt last year        40.0         7
# 18          Just as welcome now as I felt last year        45.0        19
#
#            YearsCodePro
# Respondent
# 5                     8
# 8                    13
# 14                    1
# 17                    3
# 18                   12
#
# [5 rows x 61 columns]

# %% [markdown]
# ## 4.4 read sql query

# %%
df_sql=pd.read_sql_query('SELECT * FROM "developer_survey_2020/sample_table" WHERE AGE>30', engine, index_col='Respondent')

# %%
df_sql
# Out:
#             index                                         MainBranch Hobbyist  \
# Respondent
# 5               4  I used to be a developer by profession, but no...      Yes
# 8               7                     I am a developer by profession      Yes
# 18             17                     I am a developer by profession      Yes
# 42             41                     I am a developer by profession       No
# 48             47                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 2331        64170                                               None      Yes
# 19581       64237                                               None      Yes
# 49544       64368                                               None      Yes
# 54361       64388                                               None      Yes
# 58498       64413                                               None      Yes
#
#              Age Age1stCode CompFreq  CompTotal  ConvertedComp        Country  \
# Respondent
# 5           31.0         16     None        NaN            NaN  United States
# 8           36.0         12   Yearly   116000.0       116000.0  United States
# 18          32.0         12  Monthly   105000.0      1260000.0  United States
# 42          32.0         14   Yearly   130000.0       130000.0  United States
# 48          38.0         30   Yearly   125000.0       125000.0  United States
# ...          ...        ...      ...        ...            ...            ...
# 2331        45.0          6     None        NaN            NaN  United States
# 19581       39.0          6     None        NaN            NaN  United States
# 49544       32.0         16     None        NaN            NaN  United States
# 54361       56.0         50     None        NaN            NaN  United States
# 58498       32.0         23     None        NaN            NaN  United States
#
#                     CurrencyDesc  ...                  SurveyEase  \
# Respondent                        ...
# 5                           None  ...                        Easy
# 8           United States dollar  ...                        Easy
# 18          United States dollar  ...  Neither easy nor difficult
# 42          United States dollar  ...                        Easy
# 48          United States dollar  ...                        Easy
# ...                          ...  ...                         ...
# 2331                        None  ...                        Easy
# 19581                       None  ...                        Easy
# 49544                       None  ...  Neither easy nor difficult
# 54361                       None  ...  Neither easy nor difficult
# 58498                       None  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 5                       Too short    No
# 8           Appropriate in length    No
# 18          Appropriate in length    No
# 42          Appropriate in length    No
# 48          Appropriate in length    No
# ...                           ...   ...
# 2331                     Too long    No
# 19581       Appropriate in length    No
# 49544       Appropriate in length    No
# 54361       Appropriate in length    No
# 58498       Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 5           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 18          Computer science, computer engineering, or sof...
# 42          Computer science, computer engineering, or sof...
# 48          Fine arts or performing arts (such as graphic ...
# ...                                                       ...
# 2331        Computer science, computer engineering, or sof...
# 19581       Computer science, computer engineering, or sof...
# 49544       A business discipline (such as accounting, fin...
# 54361       A health science (such as nursing, pharmacy, r...
# 58498                               Mathematics or statistics
#
#                                        WebframeDesireNextYear  \
# Respondent
# 5                                        Django;Ruby on Rails
# 8                                      Django;React.js;Vue.js
# 18                                                       None
# 42                                        ASP.NET Core;Spring
# 48                                       Gatsby;Ruby on Rails
# ...                                                       ...
# 2331                                                     None
# 19581                                                 Angular
# 49544                                            Flask;Vue.js
# 54361                                                    None
# 58498       ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React...
#
#                                            WebframeWorkedWith  \
# Respondent
# 5                                               Ruby on Rails
# 8                                                       Flask
# 18                                                       None
# 42                              ASP.NET;Flask;React.js;Spring
# 48                                       Gatsby;Ruby on Rails
# ...                                                       ...
# 2331                                                     None
# 19581                                                 Angular
# 49544                                           Express;Flask
# 54361                                          ASP.NET;jQuery
# 58498       ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React...
#
#                                                 WelcomeChange WorkWeekHrs  \
# Respondent
# 5                     Just as welcome now as I felt last year         NaN
# 8                     Just as welcome now as I felt last year        39.0
# 18                    Just as welcome now as I felt last year        45.0
# 42                   Somewhat less welcome now than last year        37.0
# 48                                                       None        30.0
# ...                                                       ...         ...
# 2331                  Just as welcome now as I felt last year         NaN
# 19581       Not applicable - I did not use Stack Overflow ...         NaN
# 49544                 Just as welcome now as I felt last year         NaN
# 54361       Not applicable - I did not use Stack Overflow ...         NaN
# 58498                                                    None         NaN
#
#            YearsCode      YearsCodePro
# Respondent
# 5                 15                 8
# 8                 17                13
# 18                19                12
# 42                16                10
# 48                 8                 8
# ...              ...               ...
# 2331              40  Less than 1 year
# 19581             38              None
# 49544             14                10
# 54361              2              None
# 58498              8  Less than 1 year
#
# [5152 rows x 61 columns]

# %% [markdown]
# # URL data (json file)

# %%
posts_df = pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
posts_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1
